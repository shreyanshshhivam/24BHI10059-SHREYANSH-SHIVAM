# %%
# !pip install fastapi uvicorn pymongo
# Out:
# ...
#      ---------------------------------------- 0.0/109.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/109.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/109.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/109.4 kB ? eta -:--:--
#      -------------------- ---------------- 61.4/109.4 kB 409.6 kB/s eta 0:00:01
#      --------------------------------- -- 102.4/109.4 kB 492.8 kB/s eta 0:00:01
#      ------------------------------------ 109.4/109.4 kB 488.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/121.9 kB ? eta -:--:--
#    ------------------------------ --------- 92.2/121.9 kB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 121.9/121.9 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/71.4 kB ? eta -:--:--
#    ---------------------------------------- 71.4/71.4 kB ? eta 0:00:00
# ...

# %%
# !pip install "pandas<3.0.0" streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 279.3 kB/s eta 0:00:40
#    ---------------------------------------- 0.0/11.0 MB 279.3 kB/s eta 0:00:40
#    ---------------------------------------- 0.1/11.0 MB 504.4 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/11.0 MB 504.4 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/11.0 MB 504.4 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/11.0 MB 504.4 kB/s eta 0:00:22
#     --------------------------------------- 0.2/11.0 MB 654.9 kB/s eta 0:00:17
#     --------------------------------------- 0.2/11.0 MB 654.9 kB/s eta 0:00:17
#    - -------------------------------------- 0.5/11.0 MB 972.0 kB/s eta 0:00:11
# ...

# %%
# !pip install pyft232
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pyft232: filename=pyft232-0.12-py3-none-any.whl size=19375 sha256=7030c64b6203043afa732502528e68e5c857ee7dd52594474e67224024b86bd5
#   Stored in directory: c:\users\shrey\appdata\local\pip\cache\wheels\88\b5\c9\f64c94406e213a8a442e0bee3ef605f71ad70d500adcdd3bea
# Successfully built pyft232
# ...

# %%
# !pip install "pandas<3.0.0" streamlit

# %%
pip install --upgrade typing-extensions fastapi pydantic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
